# %%
#pandas Series函数
import pandas as pd

num1 = pd.Series([1,2,3,4])#0123里面写入1234
print(num1)

num2 = pd.Series([1,2,3],index = ['a','b','c'])
print(num2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
#DataFrame()

import pandas as pd
list1 = [
    ['홈길동', '남자', '20', '180'],
    ['김길동', '남자', '21', '177'],
    ['박길동', '여자', '20', '160']
]
col_names = ['이름', '성별', '나이', '키']
pd.DataFrame(list1, columns=col_names)
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160

# %%
import pandas as pd

dict1 = {
    '이름': {0: '홈길동', 1: '김길동', 2: '박길동'},
    '성별': {0: '남자', 1: '남자', 2: '여자'},
    '나이': {0: '20', 1: '21', 2: '20'},
    '키': {0: '180', 1: '177', 2: '160'}
}

pd.DataFrame(dict1)
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160

# %%
import pandas as pd
list1 = ([
    ['홈길동', '남자', '20', '180'],
    ['김길동', '남자', '21', '177'],
    ['박길동', '여자', '20', '160'],
    ['이수호', '남자', '21', '182'],
    ['임주경', '여자', '17', '155'],
    ['이두니', '여자', '26', '157'],
    ['강님순', '여자', '24', '157'],
    ['도봉순', '여자', '24', '172']
])
col_names = ['이름', '성별', '나이', '키']
df=pd.DataFrame(list1,columns=col_names)

df
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df.to_csv('./file.csv', header=True, index=False, encoding='utf-8')

# %%
df2=pd.read_csv('./file.csv',sep=',')

df2
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df.columns
# Out:
# Index(['이름', '성별', '나이', '키'], dtype='object')

# %%
df.describe()
# Out:
#          이름  성별  나이    키
# count     8   8   8    8
# unique    8   2   5    7
# top     홈길동  여자  20  157
# freq      1   5   2    2

# %%
df.head(3)
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160

# %%
df.tail()
# Out:
#     이름  성별  나이    키
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df.sort_index(axis = 0).head()
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155

# %%
df.sort_values(by = ['나이','키'],ascending=False)
# Out:
#     이름  성별  나이    키
# 5  이두니  여자  26  157
# 7  도봉순  여자  24  172
# 6  강님순  여자  24  157
# 3  이수호  남자  21  182
# 1  김길동  남자  21  177
# 0  홈길동  남자  20  180
# 2  박길동  여자  20  160
# 4  임주경  여자  17  155

# %%
df[['이름','키']]
# Out:
#     이름    키
# 0  홈길동  180
# 1  김길동  177
# 2  박길동  160
# 3  이수호  182
# 4  임주경  155
# 5  이두니  157
# 6  강님순  157
# 7  도봉순  172

# %%
df
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df.iloc[1:4,0:3]
# Out:
#     이름  성별  나이
# 1  김길동  남자  21
# 2  박길동  여자  20
# 3  이수호  남자  21

# %%
import pandas as pd
list1 = ([
    ['홈길동', '남자', 20, 180],
    ['김길동', '남자', 21, 177],
    ['박길동', '여자', 20, 160],
    ['이수호', '남자', 21, 182],
    ['임주경', '여자', 17, 155],
    ['이두니', '여자', 26, 157],
    ['강님순', '여자', 24, 157],
    ['도봉순', '여자', 24, 172]
])
col_names = ['이름', '성별', '나이', '키']
df=pd.DataFrame(list1,columns=col_names)

df
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df[df['키'] > '180']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ae400c5d33c6> in <cell line: 1>()
# ----> 1 df[df['키'] > '180']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      56     @unpack_zerodim_and_defer("__gt__")
#      57     def __gt__(self, other):
# ---> 58         return self._cmp_method(other, operator.gt)
#      59
#      60     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# ...

# %%
df[df['나이'].isin([21,23])]
# Out:
#     이름  성별  나이    키
# 1  김길동  남자  21  177
# 3  이수호  남자  21  182

# %%
df[(df['성별']=='여자')&(df['키']>=160)]
# Out:
#     이름  성별  나이    키
# 2  박길동  여자  20  160
# 7  도봉순  여자  24  172

# %%
df[(df['나이']>=20)&(df['성별']=='남자')]
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 3  이수호  남자  21  182

# %%
df[df['이름']=='순']
# Out:
# Empty DataFrame
# Columns: [이름, 성별, 나이, 키]
# Index: []

# %%
df.describe()
# Out:
#               나이           키
# count   8.000000    8.000000
# mean   21.625000  167.500000
# std     2.875388   11.401754
# min    17.000000  155.000000
# 25%    20.000000  157.000000
# 50%    21.000000  166.000000
# 75%    24.000000  177.750000
# max    26.000000  182.000000

# %%
df.set_index('이름',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-5cdfba308786> in <cell line: 1>()
# ----> 1 df.set_index('이름',inplace = True)
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['이름'] are in the columns"

# %%
df.head()
# Out:
#      성별  나이    키
# 이름
# 홈길동  남자  20  180
# 김길동  남자  21  177
# 박길동  여자  20  160
# 이수호  남자  21  182
# 임주경  여자  17  155

# %%
df['보너스']=df['나이']*1000
df
# Out:
#      성별  나이    키    보너스
# 이름
# 홈길동  남자  20  180  20000
# 김길동  남자  21  177  21000
# 박길동  여자  20  160  20000
# 이수호  남자  21  182  21000
# 임주경  여자  17  155  17000
# 이두니  여자  26  157  26000
# 강님순  여자  24  157  24000
# 도봉순  여자  24  172  24000

# %%
df.drop('보너스',axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-68004637ebe5> in <cell line: 1>()
# ----> 1 df.drop('보너스',axis = 1,inplace = True)
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df.head()
# Out:
#      성별  나이    키
# 이름
# 홈길동  남자  20  180
# 김길동  남자  21  177
# 박길동  여자  20  160
# 이수호  남자  21  182
# 임주경  여자  17  155

# %%
del df['보너스']

df.head()
# Out:
#      성별  나이    키
# 이름
# 홈길동  남자  20  180
# 김길동  남자  21  177
# 박길동  여자  20  160
# 이수호  남자  21  182
# 임주경  여자  17  155

# %%
df.reset_index(inplace=True)
df
# Out:
#     이름  성별  나이    키
# 0  홈길동  남자  20  180
# 1  김길동  남자  21  177
# 2  박길동  여자  20  160
# 3  이수호  남자  21  182
# 4  임주경  여자  17  155
# 5  이두니  여자  26  157
# 6  강님순  여자  24  157
# 7  도봉순  여자  24  172

# %%
df.describe()
# Out:
#               나이           키
# count   8.000000    8.000000
# mean   21.625000  167.500000
# std     2.875388   11.401754
# min    17.000000  155.000000
# 25%    20.000000  157.000000
# 50%    21.000000  166.000000
# 75%    24.000000  177.750000
# max    26.000000  182.000000

# %%
mean_by_gender = df.groupby(by=['성별'], as_index=False).mean()

mean_by_gender.rename(columns={'키': '평균키'}, inplace=True)

mean_by_gender
# Out:
# <ipython-input-81-f0d2ef93cb9e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_by_gender = df.groupby(by=['성별'], as_index=False).mean()
#    성별         나이         평균키
# 0  남자  20.666667  179.666667
# 1  여자  22.200000  160.200000

# %%
mean_by_gender = df.groupby(by=['성별'], as_index=False).mean()

mean_by_gender.rename(columns={'키': '키의 표준 편자'}, inplace=True)

mean_by_gender
# Out:
# <ipython-input-82-a1a891821946>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_by_gender = df.groupby(by=['성별'], as_index=False).mean()
#    성별         나이    키의 표준 편자
# 0  남자  20.666667  179.666667
# 1  여자  22.200000  160.200000

# %%
new_df = pd.merge(mean_by_gender)

# %%
col_names = ['과목번호','과목명','강의실','시간표']
list1 =list([['C1','파이썬','303호',3],
       ['C2','국어','201호',3],
       ['C3','영어','203호',3],
       ['C4','한국어','201호',2],
       ['C5','과학','401호',3],
       ['C6','사회','201호',2]
             ])

# %%
import pandas as pd

timetable_df = pd.DataFrame(list1,columns=col_names)
timetable_df.to_csv('.timetable.csv',header=True,index=False,encoding='UTF-8')

# %%
timetable_df = pd.read_csv('timetable.csv')
timetable_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-91-3925d4f4ded5> in <cell line: 1>()
# ----> 1 timetable_df = pd.read_csv('timetable.csv')
#       2 timetable_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
timetable_df['담임 교사'] = ['이순신', '김유신', '강감신', '신사임당']
print(timetable_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-cde463210f5f> in <cell line: 1>()
# ----> 1 timetable_df['담임 교사'] = ['이순신', '김유신', '강감신', '신사임당']
#       2 print(timetable_df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# ...

# %%
result = timetable_df.groupby(by=['강의실'], as_index=False)['시간표'].mean()
print(result)
# Out:
#     강의실       시간표
# 0  201호  2.333333
# 1  203호  3.000000
# 2  303호  3.000000
# 3  401호  3.000000
